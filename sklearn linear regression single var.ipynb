# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
# load the input excel csv file in pandas data frame.
df = pd.read_csv('homeprice.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
# .scatter is to Plot the data points
plt.scatter(df.area ,df.price , marker='x', c='b')
# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (dollars)')
# Set the x-axis label
plt.xlabel('Size (sqft)')
#plot hypothesis
plt.plot(df.area, reg.predict(df[['area']]), c='b', linewidth=3)

# %%
# Create linear regression object
reg = linear_model.LinearRegression()
# Train the model using the training sets with independent variable area and target variable price
reg.fit(df[['area']],df.price)
reg.predict([[3000]])
# Out:
# /opt/anaconda3/envs/ML_coursera/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([587979.45205479])

# %%
#w
reg.coef_
# Out:
# array([135.78767123])

# %%
#b
reg.intercept_
# Out:
# 180616.43835616432

# %%
d = pd.read_csv('prediction .csv')
p = reg.predict(d)
# create a new column prediction and print predict p on it
d['prediction'] = p
d
# Out:
#    area    prediction
# 0  6789  1.102479e+06
# 1  7890  1.251981e+06
# 2  6780  1.101257e+06
# 3  4000  7.237671e+05
# 4  9000  1.402705e+06
# 5  6000  9.953425e+05
# 6  6570  1.072741e+06
# 7  5800  9.681849e+05
# 8  7800  1.239760e+06

# %%
# now predict values only valuable here in notebook
# to print the value in real excel
d.to_csv('prediction.csv')
# to aviod index
#d.to_csv('prediction.csv', index=false)
